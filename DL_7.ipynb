# %%
import tensorflow as tf
from tensorflow.keras.layers import SimpleRNN, Dense, Reshape, LSTM, GRU
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
import matplotlib.pyplot as plt
import numpy as np

(x_train, y_train), (x_test, y_test) = mnist.load_data()

#normalize
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

#Reshape the data
x_train = x_train.reshape((x_train.shape[0], 28, 28))
x_test = x_test.reshape((x_test.shape[0], 28, 28))

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ### Model SimpleRNN

# %%
# Define the SimpleRNN model
model = Sequential()
model.add(SimpleRNN(128, input_shape=(28, 28)))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model and store the training history
history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.8016 - loss: 0.6530 - val_accuracy: 0.9408 - val_loss: 0.2075
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9406 - loss: 0.2019 - val_accuracy: 0.9510 - val_loss: 0.1676
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9539 - loss: 0.1610 - val_accuracy: 0.9513 - val_loss: 0.1672
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9621 - loss: 0.1335 - val_accuracy: 0.9596 - val_loss: 0.1381
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9633 - loss: 0.1257 - val_accuracy: 0.9556 - val_loss: 0.1639
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9677 - loss: 0.1152 - val_accuracy: 0.9683 - val_loss: 0.1132
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9679 - loss: 0.1121 - val_accuracy: 0.9658 - val_loss: 0.1285
# Epoch 8/10
# ...

# %%
# training & validation accuracy for SimpleRNN
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy SimpleRNN')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
#  training & validation loss for SimpleRnn
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss SimpleRNN')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Model GRU

# %%
# Define the GRU model
modelGRU = Sequential()
modelGRU.add(GRU(128, input_shape=(28, 28)))
modelGRU.add(Dense(10, activation='softmax'))

# Compile the model
modelGRU.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model and store the training history
history2 = modelGRU.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6943 - loss: 0.8867 - val_accuracy: 0.9487 - val_loss: 0.1610
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9567 - loss: 0.1435 - val_accuracy: 0.9704 - val_loss: 0.0940
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9744 - loss: 0.0858 - val_accuracy: 0.9783 - val_loss: 0.0697
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9791 - loss: 0.0663 - val_accuracy: 0.9800 - val_loss: 0.0652
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9838 - loss: 0.0545 - val_accuracy: 0.9818 - val_loss: 0.0560
# Epoch 6/10
# ...

# %%
# training & validation accuracy for GRU
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model Accuracy GRU')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
#  training & validation loss for GRU
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model Loss GRU')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Model LSTM

# %%
# Define the LSTM model
modellstm = Sequential()
modellstm.add(LSTM(128, input_shape=(28, 28)))
modellstm.add(Dense(10, activation='softmax'))

# Compile the model
modellstm.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model and store the training history
history1 = modellstm.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

# prediction
predictions = model.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7356 - loss: 0.7875 - val_accuracy: 0.9501 - val_loss: 0.1589
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9611 - loss: 0.1276 - val_accuracy: 0.9710 - val_loss: 0.0924
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9744 - loss: 0.0825 - val_accuracy: 0.9772 - val_loss: 0.0724
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9802 - loss: 0.0654 - val_accuracy: 0.9805 - val_loss: 0.0599
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9857 - loss: 0.0477 - val_accuracy: 0.9782 - val_loss: 0.0766
# Epoch 6/10
# ...

# %%
# training & validation accuracy for LSTM
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model Accuracy LSTM')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
#  training & validation loss for LSTM
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model Loss LSTM')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# one hot encoding
y_test_labels = np.argmax(y_test, axis=1)
predicted_labels = np.argmax(predictions, axis=1)

# %%
# Plot real vs predicted for the first 10 test images
plt.figure(figsize=(12, 6))
for i in range(10):
    # Subplot for each digit
    plt.subplot(2, 5, i+1)
    plt.imshow(x_test[i], cmap='gray')  # Plot the image
    plt.title(f"True: {y_test_labels[i]}\nPred: {predicted_labels[i]}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## input img form user

# %%
def preprocess_handwritten_image(image_path):
    img = Image.open(image_path).convert('L')
    img = img.resize((28, 28))
    img = np.array(img)
    img = img / 255.0
    img = img.reshape(1, 28, 28)
    return img

image_path = '/content/new8.png'
handwritten_image = preprocess_handwritten_image(image_path)

# %%
prediction = modellstm.predict(handwritten_image)
predicted_digit = np.argmax(prediction)

# Display the original handwritten image and the predicted digit
plt.figure(figsize=(6, 6))
plt.subplot(1, 2, 1)
plt.imshow(np.squeeze(handwritten_image), cmap='gray')
plt.title(f"Predicted Digit: {predicted_digit}")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(create_digit_image(predicted_digit), cmap='gray')  # Function from previous code
plt.title(f"Generated Digit: {predicted_digit}")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
