# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
binary_indices = np.where(y != 2)[0]
x = x[binary_indices]
y = y[binary_indices]

# %%
#scaler = StandardScaler()
#x = scaler.fit
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
#x_train, x_test, y_train, y_test = train_test_split(x, y)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Dense(16, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer=SGD(learning_rate=0.01), loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=12, validation_split=0.2)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 1s 49ms/step - loss: 1.3277 - accuracy: 0.2289 - val_loss: 1.4429 - val_accuracy: 0.2381
# Epoch 2/20
# 7/7 [==============================] - 0s 11ms/step - loss: 1.1482 - accuracy: 0.2530 - val_loss: 1.2240 - val_accuracy: 0.2381
# Epoch 3/20
# 7/7 [==============================] - 0s 12ms/step - loss: 1.0243 - accuracy: 0.2289 - val_loss: 1.0728 - val_accuracy: 0.2857
# Epoch 4/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.9392 - accuracy: 0.2289 - val_loss: 0.9645 - val_accuracy: 0.2857
# Epoch 5/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.8718 - accuracy: 0.3373 - val_loss: 0.8848 - val_accuracy: 0.3810
# Epoch 6/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.8190 - accuracy: 0.3735 - val_loss: 0.8231 - val_accuracy: 0.3333
# Epoch 7/20
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7771 - accuracy: 0.4337 - val_loss: 0.7749 - val_accuracy: 0.3810
# Epoch 8/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.7410 - accuracy: 0.4699 - val_loss: 0.7335 - val_accuracy: 0.4286
# Epoch 9/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.7098 - accuracy: 0.5422 - val_loss: 0.6989 - val_accuracy: 0.5238
# Epoch 10/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6825 - accuracy: 0.5663 - val_loss: 0.6708 - val_accuracy: 0.5238
# Epoch 11/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6587 - accuracy: 0.6265 - val_loss: 0.6466 - val_accuracy: 0.7143
# Epoch 12/20
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6375 - accuracy: 0.6867 - val_loss: 0.6252 - val_accuracy: 0.6667
# Epoch 13/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6181 - accuracy: 0.7108 - val_loss: 0.6056 - val_accuracy: 0.7619
# Epoch 14/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.6002 - accuracy: 0.7229 - val_loss: 0.5884 - val_accuracy: 0.7619
# Epoch 15/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.5835 - accuracy: 0.7711 - val_loss: 0.5737 - val_accuracy: 0.7619
# Epoch 16/20
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5673 - accuracy: 0.8193 - val_loss: 0.5602 - val_accuracy: 0.7619
# Epoch 17/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5514 - accuracy: 0.8434 - val_loss: 0.5476 - val_accuracy: 0.8095
# Epoch 18/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.5364 - accuracy: 0.8554 - val_loss: 0.5355 - val_accuracy: 0.8095
# Epoch 19/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5213 - accuracy: 0.8795 - val_loss: 0.5238 - val_accuracy: 0.8095
# Epoch 20/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.5061 - accuracy: 0.8795 - val_loss: 0.5127 - val_accuracy: 0.8095

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}, Test Accuracy: {accuracy}')
# Out:
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4919 - accuracy: 0.9231
# Test Loss: 0.49190810322761536, Test Accuracy: 0.9230769276618958

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'],)
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(history.history['accuracy'],)
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
