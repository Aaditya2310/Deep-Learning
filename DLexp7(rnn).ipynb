# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Flatten, Reshape
from tensorflow.keras.utils import to_categorical
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Convert class vectors to binary class matrices
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
# Reshape data for RNN (treating each row of pixels as a sequence)
x_train = x_train.reshape((x_train.shape[0], 28, 28))
x_test = x_test.reshape((x_test.shape[0], 28, 28))
# Build the RNN model
model = Sequential()
model.add(SimpleRNN(64, input_shape=(28, 28), activation='relu'))
model.add(Dense(10, activation='softmax'))
# Compile the model
model.compile(optimizer='adam',
loss='categorical_crossentropy',
metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
model.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.5981 - loss: 1.1590 - val_accuracy: 0.9067 - val_loss: 0.3187
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9084 - loss: 0.3141 - val_accuracy: 0.9333 - val_loss: 0.2169
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9311 - loss: 0.2356 - val_accuracy: 0.9408 - val_loss: 0.1968
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9414 - loss: 0.2006 - val_accuracy: 0.9459 - val_loss: 0.1793
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.9468 - loss: 0.1814 - val_accuracy: 0.9549 - val_loss: 0.1503

# %%
# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f'Test accuracy: {accuracy}')
# Make predictions (optional)
predictions = model.predict(x_test)
# Out:
# 313/313 - 1s - 3ms/step - accuracy: 0.9557 - loss: 0.1563
# Test accuracy: 0.9556999802589417
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
